# %%
from utils import get_completion, get_completion_from_messages
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Creating my own chat bot

# %%
messages = [
    {
        'role': 'system',
        'content': 'You are a chatbot, respond in short'
        
    }
]
get_completion_from_messages(messages)
# Out:
# "I'm ready!"

# %%
while True:
    question = input().strip()
    messages.append({
        'role': 'user',
        'content': question
    })
    response = get_completion_from_messages(messages)
    messages.append({
        'role':'assistant', 
        'content': response
    })
    print(response)
    if question=='stop':
        break
# Out:
#  My self Ravi Kumar
# Nice to meet you, Ravi Kumar!
#  I have completed my graduation from university of lucknow
# Congratulations on completing your graduation from University of Lucknow!
#  I have also completed my masters from IIT jodhpur in mathematics
# Impressive! IIT Jodhpur is a renowned institution. You must have had a great experience pursuing your Master's in Mathematics there!
#  Now what to do next to find either job or research work or something else ?
# Congratulations on completing your Master's! Next steps could be:
#
# 1. Job search: Apply to companies, research institutions, and government organizations.
# 2. Research opportunities: Look for research positions, fellowships, or scholarships.
# 3. Pursue a Ph.D.: Consider continuing your education with a Doctoral program.
# 4. Teaching: Explore opportunities to teach at schools, colleges, or universities.
# 5. Industry applications: Apply your mathematical skills to industries like finance, data science, or consulting.
#
# Which direction are you leaning towards?
#  I want to deep dive in AI ML field.
# AI/ML is a fascinating field! To deep dive, consider:
#
# 1. Online courses: Take courses on platforms like Coursera, edX, or Udemy.
# 2. Research papers: Read and analyze papers on arXiv, ResearchGate, or Academia.edu.
# 3. Projects: Work on personal projects or contribute to open-source projects.
# 4. Certifications: Pursue certifications like Google Cloud AI, Microsoft Certified: Azure AI Engineer.
# 5. Join communities: Participate in Kaggle, Reddit (r/MachineLearning), or AI/ML forums.
# 6. Attend conferences: Look for conferences, meetups, or webinars to network and learn.
# 7. Read books: Explore books on AI/ML, such as "Deep Learning" by Ian Goodfellow.
#
# Which specific area of AI/ML interests you the most?
#  Research work
# Research work in AI/ML can be a great way to contribute to the field and advance your knowledge. Here are some steps to consider:
#
# 1. Identify a research area: Focus on a specific area, such as computer vision, natural language processing, or reinforcement learning.
# 2. Read research papers: Study recent papers in your chosen area to understand the current state-of-the-art.
# 3. Find a research group: Look for research groups or labs that align with your interests and reach out to them.
# 4. Collaborate with others: Work with others on research projects to share knowledge and ideas.
# 5. Publish your work: Share your research through papers, posters, or presentations at conferences.
# 6. Apply for research grants: Look for funding opportunities to support your research.
#
# Some popular research areas in AI/ML include:
#
# 1. Explainable AI (XAI)
# 2. Transfer learning
# 3. Adversarial attacks and defenses
# 4. Multi-modal learning
# 5. Reinforcement learning
#
# Which research area in AI/ML excites you the most?
#  Transfer learning
# Transfer learning is a fascinating area in AI/ML, where you can leverage pre-trained models and fine-tune them for specific tasks. Here are some steps to get started:
#
# 1. Learn about pre-trained models: Familiarize yourself with popular pre-trained models like VGG, ResNet, and BERT.
# 2. Choose a task: Select a specific task, such as image classification, object detection, or language translation.
# 3. Fine-tune a model: Use a pre-trained model as a starting point and fine-tune it for your chosen task.
# 4. Experiment with hyperparameters: Adjust hyperparameters like learning rate, batch size, and number of epochs to optimize performance.
# 5. Evaluate and compare: Evaluate your model's performance and compare it to other models or baselines.
#
# Some popular transfer learning applications include:
#
# 1. Image classification: Fine-tune pre-trained models for specific image classification tasks.
# 2. Object detection: Use pre-trained models for object detection tasks like YOLO or SSD.
# 3. Natural language processing: Fine-tune pre-trained language models like BERT for specific NLP tasks.
#
# Which specific application of transfer learning interests you the most?
#  NLP
# NLP is a rapidly growing field with many exciting applications. Here are some steps to get started:
#
# 1. Learn the basics: Familiarize yourself with NLP concepts like tokenization, stemming, and lemmatization.
# 2. Choose a library: Select a popular NLP library like NLTK, spaCy, or Stanford CoreNLP.
# 3. Start with text preprocessing: Learn to preprocess text data, including tokenization, stopword removal, and stemming.
# 4. Explore NLP tasks: Learn about tasks like sentiment analysis, named entity recognition, and language translation.
# 5. Practice with datasets: Work with popular NLP datasets like IMDB, 20 Newsgroups, or Stanford Sentiment Treebank.
#
# Some popular NLP applications include:
#
# 1. Sentiment analysis: Analyze text to determine sentiment (positive, negative, or neutral).
# 2. Named entity recognition: Identify and extract specific entities like names, locations, and organizations.
# 3. Language translation: Translate text from one language to another.
# 4. Text summarization: Summarize long pieces of text into shorter summaries.
#
# Which specific NLP task or application interests you the most?
#  Named entity recognition
# Named Entity Recognition (NER) is a fundamental task in NLP. Here are some steps to get started:
#
# 1. Learn about NER: Understand the basics of NER, including entity types like person, organization, location, and date.
# 2. Choose a library: Select a popular NLP library like NLTK, spaCy, or Stanford CoreNLP that has NER capabilities.
# 3. Preprocess text: Preprocess text data by tokenizing, stemming, and lemmatizing.
# 4. Train a model: Train a machine learning model on a labeled dataset to recognize entities.
# 5. Evaluate performance: Evaluate your model's performance using metrics like precision, recall, and F1-score.
#
# Some popular NER datasets include:
#
# 1. CoNLL-2003: A dataset for NER in English, with 4 entity types.
# 2. OntoNotes: A dataset for NER in English, with 9 entity types.
# 3. ACE2005: A dataset for NER in multiple languages, with 7 entity types.
#
# Some popular NER techniques include:
#
# 1. Rule-based approaches: Use hand-crafted rules to identify entities.
# 2. Machine learning approaches: Train machine learning models on labeled data.
# 3. Deep learning approaches: Use deep learning models like recurrent neural networks (RNNs) or convolutional neural networks (CNNs).
#
# Which specific NER technique or application interests you the most?
#  dl approaches
# Deep Learning (DL) approaches have revolutionized NER. Here are some popular DL-based NER techniques:
#
# 1. Recurrent Neural Networks (RNNs): Use RNNs to model sequential data and identify entities.
# 2. Convolutional Neural Networks (CNNs): Use CNNs to extract features from text data and identify entities.
# 3. Long Short-Term Memory (LSTM) networks: Use LSTMs to model long-range dependencies in text data and identify entities.
# 4. Bidirectional Encoder Representations from Transformers (BERT): Use pre-trained BERT models to fine-tune for NER tasks.
#
# Some popular DL-based NER architectures include:
#
# 1. CRF (Conditional Random Field) models: Use CRFs to model the probability of entities given the context.
# 2. Bi-LSTM-CRF models: Use Bi-LSTMs to model sequential data and CRFs to model the probability of entities.
# 3. Transformer-based models: Use transformer-based models like BERT to fine-tune for NER tasks.
#
# Some popular DL-based NER libraries include:
#
# 1. TensorFlow: Use TensorFlow to implement DL-based NER models.
# 2. PyTorch: Use PyTorch to implement DL-based NER models.
# 3. spaCy: Use spaCy to implement DL-based NER models.
#
# Which specific DL-based NER technique or architecture interests you the most?
#  stop
# It was nice chatting with you, Ravi Kumar! I hope you found our conversation helpful in exploring the world of AI/ML and NLP. If you have any more questions or need further guidance, feel free to reach out anytime. Good luck with your research and future endeavors!

# %% [markdown]
# ## Order chat bot

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
You are OrderBot, an automated service to collect orders for a pizza restaurant. \
You first greet the customer, then collects the order, \
and then asks if it's a pickup or delivery. \
You wait to collect the entire order, then summarize it and check for a final \
time if the customer wants to add anything else. \
If it's a delivery, you ask for an address. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  12.95, 10.00, 7.00 \
cheese pizza   10.95, 9.25, 6.50 \
eggplant pizza   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
bottled water 5.00 \
"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e7c7c515-498e-4be0-943f-d6f956f92e28'>
#   <div id="dc0e2509-2aa8-4c7f-82e0-18630520c622" data-root-id="e7c7c515-498e-4be0-943f-d6f956f92e28" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8c5404fa-156f-4674-8835-8f22cfb27df7":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e7c7c515-498e-4be0-943f-d6f956f92e28"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"45e37d84-c004-4b3b-9096-b86b5af1b497","attributes":{"plot_id":"e7c7c515-498e-4be0-943f-d6f956f92e28","comm_id":"5fd6773f948c48cb9214ff3f25ba94b9","client_comm_id":"ac3f4841fe884cc98264ef259ac58504"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"8c5404fa-156f-4674-8835-8f22cfb27df7","roots":{"e7c7c515-498e-4be0-943f-d6f956f92e28":"dc0e2509-2aa8-4c7f-82e0-18630520c622"},"root_ids":["e7c7c515-498e-4be0-943f-d6f956f92e28"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Column
#     [0] TextInput(placeholder='Enter text here…')
#     [1] Row
#         [0] Button(name='Chat!')
#     [2] ParamFunction(function, _pane=Column, defer_load=False, height=300, loading_indicator=True)

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
